# %%
template = """
I want to produce an article on the cheapest places to live (for renters) in {state}. Start by producing a section titled exactly as "# Cheapest Places to Live in {state}". This section should be 7 to 8 sentences and an overview of {state} within the broader context of cheapest places to live for renters.

Based on our methodology, the cheapest cities are: {listed_cities}

Next, produce one section for each of the 5 cities mentioned above. Create a standard header that starts with "## " before discussing the cities.  Talk about why the city is a great place to live given the data points below. When it comes to rent prices, do not draw any comparisons. Just focus on the data that is given and why the city is nice to live in. Try to reference actual nearby points of interest, roads, neighborhoods, parks, etc.


Data to utilize:
{post_data}
"""

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 us_state_to_abbrev
#
# NameError: name 'us_state_to_abbrev' is not defined

# %%
import os
import pandas as pd 
# StateAB to state
import re
from tabulate import tabulate
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}
    
# invert the dictionary
abbrev_to_us_state = dict(map(reversed, us_state_to_abbrev.items()))
df = pd.DataFrame(columns=['filepath', 'prompt', 'response'])

for file in [f for f in os.listdir("states") if re.search(r'[A-Z]{2}', f)]:
    state_ab = file
    
    state = abbrev_to_us_state[state_ab]
    data_file = pd.read_csv("states/"+file +"/Table/data.csv")
    data_file = data_file.sort_values(by='Score', ascending=False)[:5]
    
    my_list = ', '.join(data_file['City, State'].tolist())
    my_list += "."
    print(my_list)
    my_temp = template 
    my_temp = my_temp.replace('{state}', state.title())
    
    my_temp = my_temp.replace('{listed_cities}', my_list)
    data_data = data_file.to_markdown()
    print(data_data)
    my_temp = my_temp.replace('{post_data}', data_data)
    df.loc[len(df)] = ['states/'+file + "/chatgpt_output.txt", my_temp, '']
# Out:
# Essex Junction, VT, Winooski, VT.
# |    | City, State        |   Population |   Median Income |   Median Home Value |   2-Bed Asking Rent |   Score |
# |---:|:-------------------|-------------:|----------------:|--------------------:|--------------------:|--------:|
# |  0 | Essex Junction, VT |        10761 |           76845 |              305300 |                2325 |       0 |
# |  1 | Winooski, VT       |         7320 |           56236 |              231300 |                1705 |       0 |
# Danville, VA, Martinsville, VA, Waynesboro, VA, Roanoke, VA, Hopewell, VA.
# |    | City, State      |   Population |   Median Income |   Median Home Value |   2-Bed Asking Rent |   Score |
# |---:|:-----------------|-------------:|----------------:|--------------------:|--------------------:|--------:|
# |  0 | Danville, VA     |        40668 |           37147 |               95500 |                 700 | 99.5779 |
# ...

# %%
missed_content_urls = ['NH', "IN", 'FL', 'PA', "ME", 'HI', 'OR', "TN" ]
missed_content_pages = pd.DataFrame(columns=df.columns)
for other in missed_content_urls:
    fz = df[df['filepath'].str.contains( other)].iloc[0]
    missed_content_pages.loc[len(missed_content_pages),:] = fz.to_list()
# Out:
#                        filepath  \
# 0  states/NH/chatgpt_output.txt
# 1  states/IN/chatgpt_output.txt
# 2  states/FL/chatgpt_output.txt
# 3  states/PA/chatgpt_output.txt
# 4  states/ME/chatgpt_output.txt
# 5  states/HI/chatgpt_output.txt
# 6  states/OR/chatgpt_output.txt
# 7  states/TN/chatgpt_output.txt
#
#                                               prompt response
# 0  \nI want to produce an article on the cheapest...
# 1  \nI want to produce an article on the cheapest...
# 2  \nI want to produce an article on the cheapest...
# 3  \nI want to produce an article on the cheapest...
# 4  \nI want to produce an article on the cheapest...
# 5  \nI want to produce an article on the cheapest...
# 6  \nI want to produce an article on the cheapest...
# 7  \nI want to produce an article on the cheapest...

# %%
missed_content_pages.iloc[0,1]
# Out:
# '\nI want to produce an article on the cheapest places to live (for renters) in New Hampshire. Start by producing a section titled exactly as "# Cheapest Places to Live in New Hampshire". This section should be 7 to 8 sentences and an overview of New Hampshire within the broader context of cheapest places to live for renters.\n\nBased on our methodology, the cheapest cities are: Rochester, NH, Concord, NH, Somersworth, NH, Manchester, NH, Keene, NH.\n\nNext, produce one section for each of the 5 cities mentioned above. Create a standard header that starts with "## " before discussing the cities.  Talk about why the city is a great place to live given the data points below. When it comes to rent prices, do not draw any comparisons. Just focus on the data that is given and why the city is nice to live in. Try to reference actual nearby points of interest, roads, neighborhoods, parks, etc.\n\n\nData to utilize:\n|    | City, State     |   Population |   Median Income |   Median Home Val
# ...

# %%
import httpx
import asyncio
import time
async def call_openai_api(prompt, index):
    api_key = "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"  # Replace with your OpenAI API key
    endpoint = "https://api.openai.com/v1/chat/completions"  # Replace with the API endpoint

    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json",
    }
    
    data = {
        "model" : "gpt-4",
         "messages" : [{'content': prompt, 'role': 'user'}],
        "temperature" : .9,
        "n": 1
    }

    async with httpx.AsyncClient(timeout=900) as client:
        response = await client.post(endpoint, json=data, headers=headers)

        if response.status_code == 200:
            result = response.json()
            
            return index, result['choices'][0]['message']['content']  # Return both the index and the result
        else:
            print(response.json())
            return index, 'ERROR'



async def main(df_test):
    prompts = df_test[(df_test['response'] == "") | (df_test['response'] == "ERROR") ].prompt.to_list()#["Translate the following English text to French: 'Hello, world.'", "Generate a summary of a news article."]
    # Make asynchronous API calls
    tasks = []
    # Create and append tasks for each prompt
    for index, prompt in zip(df_test[(df_test['response'] == "") | (df_test['response'] == "ERROR") ].index,prompts):
        task = call_openai_api(prompt, index)
        tasks.append(task)

    # Gather and await tasks, maintaining order
    
    results = await asyncio.gather(*tasks)
    results.sort(key=lambda x: x[0])

    # Extract just the results (excluding the indices)
    ordered_results = pd.Series({result[0] : result[1] for result in results})
    return ordered_results
    #for idx, row in ordered_results.iteritems():
    #    df.loc[idx,'response'] = row
# 



import time
start_time = time.time()
# set DF HERE. 
runningDF = missed_content_pages
# iterates over entire DF in partitions, exec'ing 
run_error_count = 0
start_time = time.time()
# Description: 
# Until we get a response from every input, continue running "safely". 
# TO THINK ABOUT : IF heavy payload to servers, and responses are too slow, past the 35k threshold, does 34999 reruns happen ever?
# Iterates every 80 (Which was our estimated max TPM through openAI.) Into Async Calls, returns ordered responses and creates calls to OpenAI . 
# Change model in call_openai_api in cell.
# 
time_array = []
second_diff_array = []
while len(runningDF[(runningDF['response'] == "ERROR") | (runningDF['response'] == '')]) >1:
    print("Run Count:" + str(run_error_count))
    if (run_error_count > 1 and len(runningDF[(runningDF['response'] == "ERROR") | (runningDF['response'] == '')])) > 35000 or (run_error_count >=5):
        break 
    for i in range(0, len(runningDF[(runningDF['response'] == "ERROR") | (runningDF['response'] == '')]), 50):
        # Extract a slice of the DataFrame containing the current 100 rows
        if i % 800 == 0 and i != 0:
            print(str(i) + "\t: " + str(round(time.time() - start_time,2)))
            runningDF[['filepath','response']].to_csv("missed_responses.csv", index=True)
            time_array.append(start_time)
            second_diff_array.append(round(time.time() - start_time,2))
            start_time = time.time()
            
        subset = runningDF[(runningDF['response'] == "ERROR") | (runningDF['response'] == '')].iloc[i:i+50]
        rez = None 
        try:
            rez = await main(subset)
        except Exception as E: 
            print('ERROR with calls.')
        if type(rez) == pd.Series:
            for idx, row in rez.iteritems():
                runningDF.loc[idx, 'response'] = row 
        time.sleep(30)
    run_error_count += 1 
runningDF[['filepath','response']].to_csv("missed_responses.csv", index=True)
# Out:
# Run Count:0

# %%
for idx, row in runningDF.iterrows():
    #print(row[['prompt', 'response']].to_list())

        
    pd.DataFrame([[row['prompt'], row['response']]], columns=['prompt', 'response']).to_csv(row['filepath'], index=False)

# %%
# Out:
# # Cheapest Places to Live in New Mexico
#
# In the realm of affordable living, many individuals consider New Mexico an attractive option. Known for its rich culture, stunning landscapes, and lower cost of living, New Mexico stands out among other states. More specifically, for renters looking for a budget-friendly city to call home, New Mexico offers numerous options. Factors like population, median income, home value, and asking rents play crucial roles in determining affordability. According to our methodology, the five cheapest cities in New Mexico for renters include Alamogordo, Farmington, Las Cruces, Gallup, and Clovis.
#
# ## Alamogordo, NM
#
# ...
